# %%
#import all the modeules we've used before

import itertools
import numpy as np
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
import seaborn as sns

from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
import rdkit
# Render the figure in a notebook:
# %matplotlib inline  

from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
no_nontoxicnans_xtrain = pd.read_csv('no_nontoxic_nans_x_train.csv', index_col=0)
no_nontoxicnans_xtest = pd.read_csv('no_nontoxic_nans_x_test.csv', index_col=0)
no_nontoxicnans_xval = pd.read_csv('no_nontoxic_nans_x_val.csv', index_col=0)
no_nontoxicnans_ytest = pd.read_csv('no_nontoxic_nans_y_test.csv', index_col=0)
no_nontoxicnans_ytrain = pd.read_csv('no_nontoxic_nans_y_train.csv', index_col= 0)
no_nontoxicnans_yval = pd.read_csv('no_nontoxic_nans_y_val.csv', index_col=0)

#Remove all nan values from the df
mask = no_nontoxicnans_xtrain.notna().all(axis=1)

no_nontoxicnans_xtrain_clean = no_nontoxicnans_xtrain[mask]
no_nontoxicnans_ytrain_clean = no_nontoxicnans_ytrain[mask]

mask2 = no_nontoxicnans_xtest.notna().all(axis=1)

no_nontoxicnans_xtest_clean = no_nontoxicnans_xtest[mask2]
no_nontoxicnans_ytest_clean = no_nontoxicnans_ytest[mask2]

mask3 = no_nontoxicnans_xval.notna().all(axis=1)

no_nontoxicnans_xval_clean = no_nontoxicnans_xval[mask3]
no_nontoxicnans_yval_clean = no_nontoxicnans_yval[mask3]

# %%
y_binary_labelstrain = no_nontoxicnans_ytrain_clean.iloc[:, 0].map({0: "non-toxic", 1: "toxic"})
y_binary_labelstest = no_nontoxicnans_ytest_clean.iloc[:, 0].map({0: "non-toxic", 1: "toxic"})

# %%
### code with the sigmoid function data

MLPC5 = MLPClassifier(hidden_layer_sizes=(10,10,5), activation='tanh', alpha=0, tol=0.001, max_iter=250, solver='sgd', random_state=0, verbose=True)

### Below finish the code to fit and predict the data
MLPC5.fit(no_nontoxicnans_xtrain_clean,no_nontoxicnans_ytrain_clean)

y_MLPC5_train = MLPC5.predict(no_nontoxicnans_xtrain_clean)
y_MLPC5_val = MLPC5.predict(no_nontoxicnans_xval_clean)

MLPC5_train_bacc = balanced_accuracy_score(no_nontoxicnans_ytrain_clean, y_MLPC5_train)
MLPC5_val_bacc = balanced_accuracy_score(no_nontoxicnans_yval_clean, y_MLPC5_val)
    
print('Balanced Accuracy train:',MLPC5_train_bacc)
print('Balanced Accuracy validation:',MLPC5_val_bacc)
# Out:
# c:\Users\dx21006\.conda\envs\chem-ml-env\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.87480654
# Iteration 2, loss = 0.79993874
# Iteration 3, loss = 0.73128095
# Iteration 4, loss = 0.68001499
# Iteration 5, loss = 0.64418068
# Iteration 6, loss = 0.62012245
# Iteration 7, loss = 0.60210967
# Iteration 8, loss = 0.58964427
# Iteration 9, loss = 0.57963010
# Iteration 10, loss = 0.57165663
# Iteration 11, loss = 0.56571895
# Iteration 12, loss = 0.56011365
# Iteration 13, loss = 0.55596589
# Iteration 14, loss = 0.55225975
# Iteration 15, loss = 0.54935485
# Iteration 16, loss = 0.54646548
# Iteration 17, loss = 0.54387847
# Iteration 18, loss = 0.54140077
# Iteration 19, loss = 0.53895167
# Iteration 20, loss = 0.53701333
# Iteration 21, loss = 0.53504453
# Iteration 22, loss = 0.53320865
# Iteration 23, loss = 0.53145900
# Iteration 24, loss = 0.52961984
# Iteration 25, loss = 0.52805409
# Iteration 26, loss = 0.52652455
# Iteration 27, loss = 0.52498262
# Iteration 28, loss = 0.52354824
# Iteration 29, loss = 0.52196060
# Iteration 30, loss = 0.52057264
# Iteration 31, loss = 0.51896282
# Iteration 32, loss = 0.51769954
# Iteration 33, loss = 0.51634555
# Iteration 34, loss = 0.51490061
# Iteration 35, loss = 0.51377301
# Iteration 36, loss = 0.51253297
# Iteration 37, loss = 0.51126811
# Iteration 38, loss = 0.51011800
# Iteration 39, loss = 0.50904953
# Iteration 40, loss = 0.50763001
# Iteration 41, loss = 0.50660888
# Iteration 42, loss = 0.50546561
# Iteration 43, loss = 0.50455769
# Iteration 44, loss = 0.50364048
# Iteration 45, loss = 0.50236610
# Iteration 46, loss = 0.50123183
# Iteration 47, loss = 0.50020817
# Iteration 48, loss = 0.49910637
# Iteration 49, loss = 0.49828154
# Iteration 50, loss = 0.49734804
# Iteration 51, loss = 0.49641534
# Iteration 52, loss = 0.49551563
# Iteration 53, loss = 0.49460925
# Iteration 54, loss = 0.49372800
# Iteration 55, loss = 0.49256886
# Iteration 56, loss = 0.49171686
# Iteration 57, loss = 0.49071876
# Iteration 58, loss = 0.48987308
# Iteration 59, loss = 0.48877049
# Iteration 60, loss = 0.48799495
# Iteration 61, loss = 0.48727041
# Iteration 62, loss = 0.48667765
# Iteration 63, loss = 0.48593284
# Iteration 64, loss = 0.48516658
# Iteration 65, loss = 0.48452719
# Iteration 66, loss = 0.48386681
# Iteration 67, loss = 0.48325481
# Iteration 68, loss = 0.48226678
# Iteration 69, loss = 0.48159472
# Iteration 70, loss = 0.48097383
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Balanced Accuracy train: 0.7799951061858308
# Balanced Accuracy validation: 0.763395679662803
