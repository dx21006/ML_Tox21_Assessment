# %%
#import all the modeules we've used before

import itertools
import numpy as np
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
import seaborn as sns

from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
import rdkit
# Render the figure in a notebook:
# %matplotlib inline  

from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
no_nontoxicnans_xtrain = pd.read_csv('no_nontoxic_nans_x_train.csv', index_col=0)
no_nontoxicnans_xtest = pd.read_csv('no_nontoxic_nans_x_test.csv', index_col=0)
no_nontoxicnans_xval = pd.read_csv('no_nontoxic_nans_x_val.csv', index_col=0)
no_nontoxicnans_ytest = pd.read_csv('no_nontoxic_nans_y_test.csv', index_col=0)
no_nontoxicnans_ytrain = pd.read_csv('no_nontoxic_nans_y_train.csv', index_col= 0)
no_nontoxicnans_yval = pd.read_csv('no_nontoxic_nans_y_val.csv', index_col=0)

#Remove all nan values from the df
mask = no_nontoxicnans_xtrain.notna().all(axis=1)

no_nontoxicnans_xtrain_clean = no_nontoxicnans_xtrain[mask]
no_nontoxicnans_ytrain_clean = no_nontoxicnans_ytrain[mask]

mask2 = no_nontoxicnans_xtest.notna().all(axis=1)

no_nontoxicnans_xtest_clean = no_nontoxicnans_xtest[mask2]
no_nontoxicnans_ytest_clean = no_nontoxicnans_ytest[mask2]

mask3 = no_nontoxicnans_xval.notna().all(axis=1)

no_nontoxicnans_xval_clean = no_nontoxicnans_xval[mask3]
no_nontoxicnans_yval_clean = no_nontoxicnans_yval[mask3]

# %%
y_binary_labelstrain = no_nontoxicnans_ytrain_clean.iloc[:, 0].map({0: "non-toxic", 1: "toxic"})
y_binary_labelstest = no_nontoxicnans_ytest_clean.iloc[:, 0].map({0: "non-toxic", 1: "toxic"})

# %%
### code with the sigmoid function data

MLPC5 = MLPClassifier(hidden_layer_sizes=(10,5), activation='relu', alpha=0, tol=0.001, max_iter=250, solver='sgd', random_state=0, verbose=True)

### Below finish the code to fit and predict the data
MLPC5.fit(no_nontoxicnans_xtrain_clean,no_nontoxicnans_ytrain_clean)

y_MLPC5_train = MLPC5.predict(no_nontoxicnans_xtrain_clean)
y_MLPC5_val = MLPC5.predict(no_nontoxicnans_xval_clean)

MLPC5_train_bacc = balanced_accuracy_score(no_nontoxicnans_ytrain_clean, y_MLPC5_train)
MLPC5_val_bacc = balanced_accuracy_score(no_nontoxicnans_yval_clean, y_MLPC5_val)
    
print('Balanced Accuracy train:',MLPC5_train_bacc)
print('Balanced Accuracy validation:',MLPC5_val_bacc)
# Out:
# c:\Users\nn21147\.conda\envs\chem-ml-env\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.91187099
# Iteration 2, loss = 0.74918174
# Iteration 3, loss = 0.67312635
# Iteration 4, loss = 0.64013395
# Iteration 5, loss = 0.62202871
# Iteration 6, loss = 0.61051770
# Iteration 7, loss = 0.60301490
# Iteration 8, loss = 0.59690296
# Iteration 9, loss = 0.59196722
# Iteration 10, loss = 0.58784019
# Iteration 11, loss = 0.58413876
# Iteration 12, loss = 0.58080388
# Iteration 13, loss = 0.57770756
# Iteration 14, loss = 0.57519610
# Iteration 15, loss = 0.57271233
# Iteration 16, loss = 0.57056528
# Iteration 17, loss = 0.56842733
# Iteration 18, loss = 0.56638903
# Iteration 19, loss = 0.56443561
# Iteration 20, loss = 0.56272162
# Iteration 21, loss = 0.56110480
# Iteration 22, loss = 0.55972265
# Iteration 23, loss = 0.55834718
# Iteration 24, loss = 0.55698040
# Iteration 25, loss = 0.55550653
# Iteration 26, loss = 0.55418253
# Iteration 27, loss = 0.55284380
# Iteration 28, loss = 0.55174873
# Iteration 29, loss = 0.55037138
# Iteration 30, loss = 0.54908637
# Iteration 31, loss = 0.54804297
# Iteration 32, loss = 0.54658113
# Iteration 33, loss = 0.54529691
# Iteration 34, loss = 0.54434691
# Iteration 35, loss = 0.54303266
# Iteration 36, loss = 0.54191112
# Iteration 37, loss = 0.54095078
# Iteration 38, loss = 0.53984763
# Iteration 39, loss = 0.53871697
# Iteration 40, loss = 0.53757492
# Iteration 41, loss = 0.53644947
# Iteration 42, loss = 0.53539562
# Iteration 43, loss = 0.53445077
# Iteration 44, loss = 0.53356080
# Iteration 45, loss = 0.53247189
# Iteration 46, loss = 0.53130407
# Iteration 47, loss = 0.53035034
# Iteration 48, loss = 0.52938518
# Iteration 49, loss = 0.52843293
# Iteration 50, loss = 0.52747589
# Iteration 51, loss = 0.52655812
# Iteration 52, loss = 0.52583709
# Iteration 53, loss = 0.52482024
# Iteration 54, loss = 0.52396157
# Iteration 55, loss = 0.52312517
# Iteration 56, loss = 0.52206455
# Iteration 57, loss = 0.52113459
# Iteration 58, loss = 0.52025480
# Iteration 59, loss = 0.51939053
# Iteration 60, loss = 0.51854908
# Iteration 61, loss = 0.51786965
# Iteration 62, loss = 0.51702080
# Iteration 63, loss = 0.51628594
# Iteration 64, loss = 0.51569140
# Iteration 65, loss = 0.51509193
# Iteration 66, loss = 0.51415022
# Iteration 67, loss = 0.51349046
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Balanced Accuracy train: 0.7598234935374327
# Balanced Accuracy validation: 0.7418664383561644
